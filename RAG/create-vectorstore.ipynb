# %%
from langchain_chroma import Chroma, vectorstores
from langchain_openai import OpenAIEmbeddings
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from prompt_toolkit import document

# 1. 문서로드 및 청킹
loader = PyPDFLoader("./data/DB_fis-내가 작성한 이력서.pdf")
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(chunk_size=800, chunk_overlap=150)
chunks = splitter.split_documents(documents)

# 2. 벡터스토어 생성
vectorstores = Chroma.from_documents(
    documents=chunks,
    embedding=OpenAIEmbeddings(
        base_url="http://localhost:1234/v1",
        model="text-embedding-nomic-embed-text-v2-moe",
        check_embedding_ctx_length=False
    ),
    collection_name="resume_docs",
    persist_directory="./chroma_db"
)

print(f"저장된 문서 수: {vectorstores._collection.count()}")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_31640\501989172.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# 저장된 문서 수: 9
